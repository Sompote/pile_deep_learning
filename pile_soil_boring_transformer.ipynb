# %% [markdown]
# <a href="https://colab.research.google.com/github/Sompote/pile_deep_learning/blob/main/pile_soil_boring_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pile analysis
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import pandas as pd
import keras
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style

df_pile=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Data/pile_soil_data.xlsx',sheet_name='pile')
df_soil=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Data/pile_soil_data.xlsx',sheet_name='soil')
df_soil=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Data/pile_soil_data.xlsx',sheet_name='pile_deform')

data_pile=np.array(df_pile)
data_soil=np.array(df_soil)
data_pile_deform=np.array(df_soil)

pile_load=data_pile[:,0:9]
pile_feature=data_pile[:,13:16]
pile_deform=data_pile_deform[:,0:9]

# %%
data_soil.shape
# Out:
# (3, 11)

# %%
#scale data
x_soil=data_soil
x_feature=pile_feature
x_deform=pile_deform
Y_train=pile_load
sc_x_soil=StandardScaler()
sc_x_feature=StandardScaler()
sc_x_deform=StandardScaler()
sc_Y_train=StandardScaler()



sc = StandardScaler()
sc_f=StandardScaler()

X_train_soil = sc_x_soil.fit_transform(x_soil)
y_train=sc_Y_train.fit_transform(Y_train)
X_feature=sc_x_feature.fit_transform(x_feature)
X_deform=sc_x_deform.fit_transform(x_deform)
X_deform=np.reshape(X_deform,(X_deform.shape[0],X_deform.shape[1],1))
X_train_soil=np.reshape(X_train_soil,(X_train_soil.shape[0],X_train_soil.shape[1],1))

# %%
X_train_soil, X_test_soil, X_feature_train, X_feature_test, X_train_deform, X_test_deform,Y_train, Y_test=train_test_split(X_train_soil, X_feature, X_deform,y_train, test_size=0.1)

# %%
X_train_deform.shape
# Out:
# (2, 9, 1)

# %%
#Model generation part
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv1D, Flatten, concatenate,Reshape, Dropout
from keras.layers import MaxPooling1D
from keras.layers import LSTM, Dense
from tensorflow.keras.metrics import MeanAbsolutePercentageError
#from attention import Attention




def CNN_model(cnn_input_shape):
  # Create the CNN model
  cnn_input = Input(shape=cnn_input_shape,name='CNN_input')
  cnn_output = Conv1D(filters=64, kernel_size=4, activation='relu',name='CNN_layer')(cnn_input)
  cnn_output = Conv1D(filters=64, kernel_size=4, activation='relu')(cnn_output)
  #cnn_output = Attention(units=32)(cnn_output)

  cnn_output = Flatten()(cnn_output)
  cnn_output = Dense(50, activation='linear')(cnn_output)
  cnn_model = Model(inputs=cnn_input, outputs=cnn_output)
  return cnn_model

def dense_model(dense_input_shape):
  # Create the dense model
  # Use the function parameter as the input shape
  dense_input = Input(shape=dense_input_shape,name='feature_input')
  dense_output = Dense(20,activation='sigmoid')(dense_input)
  dense_output = Dense(100,activation='sigmoid')(dense_input)
  dense_output = Dense(20, activation='sigmoid')(dense_output)
  layer=Dropout(0.2)(dense_output)
  dense_output = Dense(20, activation='linear')(layer)
  dense_model = Model(inputs=dense_input, outputs=dense_output)
  return dense_model



def LSTM_model(dense_input_shape):
  # Create the dense model
  # Use the function parameter as the input shape
  dense_input = Input(shape=dense_input_shape)
  layer = LSTM(20,return_sequences=True)(dense_input)
  #dense_output = Attention(units=32)(dense_output)
  layer = Flatten()(layer)
  dense_output = Dense(200, activation='sigmoid')(layer)
  layer=Dropout(0.2)(layer)
  dense_output = Dense(20, activation='linear')(layer)
  dense_model = Model(inputs=dense_input, outputs=dense_output,name='feature model')
  return dense_model

def LSTM_model2(dense_input_shape):
  # Create the dense model
  # Use the function parameter as the input shape
  dense_input = Input(shape=dense_input_shape)
  layer = LSTM(20,return_sequences=True)(dense_input)
  #dense_output = Attention(units=32)(dense_output)
  layer = Flatten()(layer)
  dense_output = Dense(200, activation='sigmoid')(layer)
  layer=Dropout(0.2)(layer)
  dense_output = Dense(20, activation='linear')(layer)
  dense_model = Model(inputs=dense_input, outputs=dense_output,name='feature model')
  return dense_model

def encoding_model(LSTM_model_soil,LSTM_model_load, cnn_model,latent_dim):
  combined_input_cnn = cnn_model.output
  combined_input_LSTM = LSTM_model_soil.output
  combined_input_LSTM_load = LSTM_model_load.output

  combined_input = concatenate([combined_input_LSTM,combined_input_cnn])
  layer=Dense(200, activation='sigmoid')(combined_input)
  layer=Dropout(0.2)(layer)
  layer=Dense(dense_input_shape, activation='sigmoid')(layer)
  combined_input2 = concatenate([combined_input_LSTM_load,layer])
  layer=Dense(50, activation='sigmoid')(combined_input2)


  combined_output = Dense(latent_dim, activation='linear')(layer)
  combined_model = Model(inputs=[LSTM_model_soil.input,cnn_model.input,LSTM_model_load.input], outputs=combined_output,name='encoding_model')
  return combined_model


def decoding_model(latent_dim,feature_dim,time_step):
  inputs_l = Input(shape=latent_dim, name='latent')
  layer_int=  Dense(40, activation='sigmoid')(inputs_l)
  layer=Dense(200, activation='sigmoid')(layer_int)
  layer=Dense(100, activation='relu')(layer)
  dense_output = Dense(time_step, activation='linear')(layer)
  output=dense_output
  model = Model([inputs_l], outputs=output,name='decoding_model')
  return model

def transformer(encoding_model,decoding_model,feature_dim):
  input_l=encoding_model.output
  print(input_l)
  outputs = decoding_model([input_l])
  print(outputs)
  model = Model(inputs=[encoding_model.input], outputs=outputs)
  return model



# Compile and summarize the combined model
#Main program

dense_input_shape = (X_train_soil.shape[1])
LSTM_input_shape=(X_train_soil.shape[1],X_train_soil.shape[2])
LSTM2_input_shape=(X_train_deform.shape[1],X_train_deform.shape[2])


feature_dim=X_feature.shape[1]
latent_dim=15
time_step=Y_train.shape[1]
#model_cnn=CNN_model(cnn_input_shape)
model_lstm_soil= LSTM_model(LSTM_input_shape)
mpdel_lstm_load=LSTM_model2(LSTM2_input_shape)
model_dense=dense_model(feature_dim)

#model_combind=combind_model2(model_lstm,model_cnn,y_train)
model_encoding=encoding_model(LSTM_model_soil= model_lstm_soil,LSTM_model_load=mpdel_lstm_load,
                              cnn_model=model_dense,latent_dim=latent_dim)
model_decoding=decoding_model(latent_dim,feature_dim,time_step)
model_transform=transformer(model_encoding,model_decoding,feature_dim)
model_transform.compile(optimizer='adam', loss='mse', metrics=['mae','mape'])
model_transform.summary()


from tensorflow.keras.callbacks import EarlyStopping
callback = EarlyStopping(monitor='loss', patience=6,restore_best_weights=True)

history=model_transform.fit([X_train_soil,X_feature_train,X_train_deform], Y_train, epochs=500, batch_size=6,validation_data=([X_test_soil,X_feature_test,X_test_deform], Y_test))
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 15), dtype=tf.float32, name=None), name='dense_59/BiasAdd:0', description="created by layer 'dense_59'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 9), dtype=tf.float32, name=None), name='decoding_model/dense_63/BiasAdd:0', description="created by layer 'decoding_model'")
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 11, 1)]      0           []
#
#  feature_input (InputLayer)     [(None, 3)]          0           []
#
#  lstm_6 (LSTM)                  (None, 11, 20)       1760        ['input_7[0][0]']
#
#  dense_53 (Dense)               (None, 100)          400         ['feature_input[0][0]']
#
#  flatten_6 (Flatten)            (None, 220)          0           ['lstm_6[0][0]']
#
#  dense_54 (Dense)               (None, 20)           2020        ['dense_53[0][0]']
#
#  dropout_12 (Dropout)           (None, 220)          0           ['flatten_6[0][0]']
#
#  dropout_14 (Dropout)           (None, 20)           0           ['dense_54[0][0]']
#
#  input_8 (InputLayer)           [(None, 9, 1)]       0           []
#
#  dense_49 (Dense)               (None, 20)           4420        ['dropout_12[0][0]']
#
#  dense_55 (Dense)               (None, 20)           420         ['dropout_14[0][0]']
#
#  lstm_7 (LSTM)                  (None, 9, 20)        1760        ['input_8[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 40)           0           ['dense_49[0][0]',
#                                                                   'dense_55[0][0]']
#
#  flatten_7 (Flatten)            (None, 180)          0           ['lstm_7[0][0]']
#
#  dense_56 (Dense)               (None, 200)          8200        ['concatenate_6[0][0]']
#
#  dropout_13 (Dropout)           (None, 180)          0           ['flatten_7[0][0]']
#
#  dropout_15 (Dropout)           (None, 200)          0           ['dense_56[0][0]']
#
#  dense_51 (Dense)               (None, 20)           3620        ['dropout_13[0][0]']
#
#  dense_57 (Dense)               (None, 11)           2211        ['dropout_15[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 31)           0           ['dense_51[0][0]',
#                                                                   'dense_57[0][0]']
#
#  dense_58 (Dense)               (None, 50)           1600        ['concatenate_7[0][0]']
#
#  dense_59 (Dense)               (None, 15)           765         ['dense_58[0][0]']
#
#  decoding_model (Functional)    (None, 9)            29849       ['dense_59[0][0]']
#
# ==================================================================================================
# Total params: 57,025
# Trainable params: 57,025
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 1/1 [==============================] - 7s 7s/step - loss: 1.1078 - mae: 0.8799 - mape: 10094316.0000 - val_loss: 1.5116 - val_mae: 1.1109 - val_mape: 107.9625
# Epoch 2/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.8932 - mae: 0.7944 - mape: 23439120.0000 - val_loss: 1.8995 - val_mae: 1.2767 - val_mape: 125.8832
# Epoch 3/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.7832 - mae: 0.7511 - mape: 32460930.0000 - val_loss: 2.2405 - val_mae: 1.4138 - val_mape: 141.3291
# Epoch 4/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.7347 - mae: 0.7468 - mape: 38777148.0000 - val_loss: 2.5086 - val_mae: 1.5163 - val_mape: 153.2456
# Epoch 5/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7244 - mae: 0.7576 - mape: 42352464.0000 - val_loss: 2.7113 - val_mae: 1.5900 - val_mape: 162.0573
# Epoch 6/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.7345 - mae: 0.7629 - mape: 43619868.0000 - val_loss: 2.8437 - val_mae: 1.6364 - val_mape: 167.7420
# Epoch 7/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.7512 - mae: 0.7651 - mape: 42533080.0000 - val_loss: 2.9021 - val_mae: 1.6594 - val_mape: 170.9195
# Epoch 8/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.7640 - mae: 0.7608 - mape: 40809220.0000 - val_loss: 2.9003 - val_mae: 1.6622 - val_mape: 171.6278
# Epoch 9/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.7677 - mae: 0.7550 - mape: 39126860.0000 - val_loss: 2.8564 - val_mae: 1.6507 - val_mape: 170.5285
# Epoch 10/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.7637 - mae: 0.7503 - mape: 37306060.0000 - val_loss: 2.7851 - val_mae: 1.6291 - val_mape: 168.0999
# Epoch 11/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.7540 - mae: 0.7470 - mape: 35228628.0000 - val_loss: 2.6988 - val_mae: 1.6010 - val_mape: 164.7763
# Epoch 12/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.7429 - mae: 0.7453 - mape: 33089636.0000 - val_loss: 2.6075 - val_mae: 1.5693 - val_mape: 160.9384
# Epoch 13/500
# 1/1 [==============================] - 0s 95ms/step - loss: 0.7330 - mae: 0.7465 - mape: 31084280.0000 - val_loss: 2.5163 - val_mae: 1.5363 - val_mape: 156.9317
# Epoch 14/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.7262 - mae: 0.7473 - mape: 29896846.0000 - val_loss: 2.4309 - val_mae: 1.5044 - val_mape: 153.0413
# Epoch 15/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.7220 - mae: 0.7467 - mape: 29070060.0000 - val_loss: 2.3537 - val_mae: 1.4752 - val_mape: 149.5255
# Epoch 16/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.7197 - mae: 0.7457 - mape: 28544698.0000 - val_loss: 2.2861 - val_mae: 1.4500 - val_mape: 146.5479
# Epoch 17/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.7189 - mae: 0.7434 - mape: 28221026.0000 - val_loss: 2.2313 - val_mae: 1.4294 - val_mape: 144.1534
# Epoch 18/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.7193 - mae: 0.7402 - mape: 28218612.0000 - val_loss: 2.1911 - val_mae: 1.4142 - val_mape: 142.4023
# Epoch 19/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.7206 - mae: 0.7386 - mape: 28697284.0000 - val_loss: 2.1663 - val_mae: 1.4045 - val_mape: 141.3083
# Epoch 20/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.7221 - mae: 0.7406 - mape: 29667856.0000 - val_loss: 2.1566 - val_mae: 1.4004 - val_mape: 140.8430
# Epoch 21/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.7237 - mae: 0.7431 - mape: 31177128.0000 - val_loss: 2.1604 - val_mae: 1.4013 - val_mape: 140.9404
# Epoch 22/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.7248 - mae: 0.7449 - mape: 33130340.0000 - val_loss: 2.1751 - val_mae: 1.4064 - val_mape: 141.5084
# Epoch 23/500
# 1/1 [==============================] - 0s 100ms/step - loss: 0.7248 - mae: 0.7452 - mape: 35279764.0000 - val_loss: 2.1972 - val_mae: 1.4146 - val_mape: 142.4468
# Epoch 24/500
# 1/1 [==============================] - 0s 96ms/step - loss: 0.7242 - mae: 0.7459 - mape: 37280616.0000 - val_loss: 2.2225 - val_mae: 1.4247 - val_mape: 143.6413
# Epoch 25/500
# 1/1 [==============================] - 0s 91ms/step - loss: 0.7227 - mae: 0.7463 - mape: 38814404.0000 - val_loss: 2.2491 - val_mae: 1.4356 - val_mape: 144.9665
# Epoch 26/500
# 1/1 [==============================] - 0s 92ms/step - loss: 0.7209 - mae: 0.7465 - mape: 39814060.0000 - val_loss: 2.2746 - val_mae: 1.4466 - val_mape: 146.3156
# Epoch 27/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.7193 - mae: 0.7465 - mape: 40127740.0000 - val_loss: 2.2975 - val_mae: 1.4568 - val_mape: 147.6006
# Epoch 28/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.7173 - mae: 0.7462 - mape: 39749932.0000 - val_loss: 2.3109 - val_mae: 1.4644 - val_mape: 148.6615
# Epoch 29/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.7158 - mae: 0.7464 - mape: 38240468.0000 - val_loss: 2.3238 - val_mae: 1.4712 - val_mape: 149.5980
# Epoch 30/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.7147 - mae: 0.7459 - mape: 36479840.0000 - val_loss: 2.3376 - val_mae: 1.4775 - val_mape: 150.4111
# Epoch 31/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.7141 - mae: 0.7448 - mape: 34716608.0000 - val_loss: 2.3534 - val_mae: 1.4835 - val_mape: 151.1143
# Epoch 32/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.7143 - mae: 0.7431 - mape: 33195300.0000 - val_loss: 2.3715 - val_mae: 1.4894 - val_mape: 151.7258
# Epoch 33/500
# 1/1 [==============================] - 0s 105ms/step - loss: 0.7145 - mae: 0.7406 - mape: 32085370.0000 - val_loss: 2.3911 - val_mae: 1.4951 - val_mape: 152.2617
# Epoch 34/500
# 1/1 [==============================] - 0s 107ms/step - loss: 0.7147 - mae: 0.7375 - mape: 31415714.0000 - val_loss: 2.4108 - val_mae: 1.5005 - val_mape: 152.7281
# Epoch 35/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.7151 - mae: 0.7373 - mape: 31207144.0000 - val_loss: 2.4283 - val_mae: 1.5051 - val_mape: 153.1090
# Epoch 36/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.7150 - mae: 0.7402 - mape: 31291608.0000 - val_loss: 2.4414 - val_mae: 1.5084 - val_mape: 153.3752
# Epoch 37/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.7151 - mae: 0.7427 - mape: 31536032.0000 - val_loss: 2.4482 - val_mae: 1.5100 - val_mape: 153.4899
# Epoch 38/500
# 1/1 [==============================] - 0s 101ms/step - loss: 0.7148 - mae: 0.7446 - mape: 31891142.0000 - val_loss: 2.4477 - val_mae: 1.5095 - val_mape: 153.4209
# Epoch 39/500
# 1/1 [==============================] - 0s 101ms/step - loss: 0.7141 - mae: 0.7454 - mape: 32234270.0000 - val_loss: 2.4399 - val_mae: 1.5068 - val_mape: 153.1521
# Epoch 40/500
# 1/1 [==============================] - 0s 89ms/step - loss: 0.7131 - mae: 0.7452 - mape: 32463700.0000 - val_loss: 2.4259 - val_mae: 1.5023 - val_mape: 152.6941
# Epoch 41/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.7115 - mae: 0.7438 - mape: 32692070.0000 - val_loss: 2.4078 - val_mae: 1.4965 - val_mape: 152.0922
# Epoch 42/500
# 1/1 [==============================] - 0s 105ms/step - loss: 0.7115 - mae: 0.7427 - mape: 32978278.0000 - val_loss: 2.3880 - val_mae: 1.4900 - val_mape: 151.4101
# Epoch 43/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.7105 - mae: 0.7404 - mape: 33222450.0000 - val_loss: 2.3687 - val_mae: 1.4836 - val_mape: 150.7229
# Epoch 44/500
# 1/1 [==============================] - 0s 100ms/step - loss: 0.7096 - mae: 0.7382 - mape: 33510398.0000 - val_loss: 2.3517 - val_mae: 1.4779 - val_mape: 150.1056
# Epoch 45/500
# 1/1 [==============================] - 0s 103ms/step - loss: 0.7088 - mae: 0.7358 - mape: 33799232.0000 - val_loss: 2.3381 - val_mae: 1.4734 - val_mape: 149.6152
# Epoch 46/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.7076 - mae: 0.7343 - mape: 34114312.0000 - val_loss: 2.3282 - val_mae: 1.4702 - val_mape: 149.2833
# Epoch 47/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.7067 - mae: 0.7335 - mape: 34441188.0000 - val_loss: 2.3215 - val_mae: 1.4684 - val_mape: 149.1133
# Epoch 48/500
# 1/1 [==============================] - 0s 95ms/step - loss: 0.7056 - mae: 0.7337 - mape: 34658592.0000 - val_loss: 2.3171 - val_mae: 1.4676 - val_mape: 149.0893
# Epoch 49/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.7037 - mae: 0.7338 - mape: 34691696.0000 - val_loss: 2.3142 - val_mae: 1.4676 - val_mape: 149.1809
# Epoch 50/500
# 1/1 [==============================] - 0s 103ms/step - loss: 0.7011 - mae: 0.7333 - mape: 34562772.0000 - val_loss: 2.3121 - val_mae: 1.4681 - val_mape: 149.3557
# Epoch 51/500
# 1/1 [==============================] - 0s 99ms/step - loss: 0.6997 - mae: 0.7335 - mape: 34268596.0000 - val_loss: 2.3107 - val_mae: 1.4689 - val_mape: 149.5852
# Epoch 52/500
# 1/1 [==============================] - 0s 96ms/step - loss: 0.6955 - mae: 0.7318 - mape: 33678260.0000 - val_loss: 2.3105 - val_mae: 1.4702 - val_mape: 149.8615
# Epoch 53/500
# 1/1 [==============================] - 0s 103ms/step - loss: 0.6914 - mae: 0.7297 - mape: 33237756.0000 - val_loss: 2.3119 - val_mae: 1.4719 - val_mape: 150.2056
# Epoch 54/500
# 1/1 [==============================] - 0s 88ms/step - loss: 0.6871 - mae: 0.7273 - mape: 32616608.0000 - val_loss: 2.3157 - val_mae: 1.4744 - val_mape: 150.6375
# Epoch 55/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6833 - mae: 0.7248 - mape: 32082714.0000 - val_loss: 2.3228 - val_mae: 1.4779 - val_mape: 151.1811
# Epoch 56/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.6742 - mae: 0.7190 - mape: 31582950.0000 - val_loss: 2.3330 - val_mae: 1.4825 - val_mape: 151.8694
# Epoch 57/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6662 - mae: 0.7143 - mape: 31098716.0000 - val_loss: 2.3461 - val_mae: 1.4882 - val_mape: 152.6980
# Epoch 58/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6557 - mae: 0.7083 - mape: 30510884.0000 - val_loss: 2.3614 - val_mae: 1.4946 - val_mape: 153.6414
# Epoch 59/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6447 - mae: 0.7026 - mape: 29918334.0000 - val_loss: 2.3779 - val_mae: 1.5013 - val_mape: 154.6495
# Epoch 60/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.6344 - mae: 0.6973 - mape: 29210312.0000 - val_loss: 2.3946 - val_mae: 1.5080 - val_mape: 155.6536
# Epoch 61/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6143 - mae: 0.6872 - mape: 28627618.0000 - val_loss: 2.4101 - val_mae: 1.5142 - val_mape: 156.6650
# Epoch 62/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5934 - mae: 0.6764 - mape: 27478754.0000 - val_loss: 2.4231 - val_mae: 1.5196 - val_mape: 157.6311
# Epoch 63/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5709 - mae: 0.6641 - mape: 26413766.0000 - val_loss: 2.4335 - val_mae: 1.5242 - val_mape: 158.5625
# Epoch 64/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.5490 - mae: 0.6517 - mape: 24896842.0000 - val_loss: 2.4437 - val_mae: 1.5284 - val_mape: 159.5167
# Epoch 65/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.5167 - mae: 0.6329 - mape: 22897402.0000 - val_loss: 2.4542 - val_mae: 1.5324 - val_mape: 160.4852
# Epoch 66/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4777 - mae: 0.6097 - mape: 20304268.0000 - val_loss: 2.4762 - val_mae: 1.5398 - val_mape: 162.0189
# Epoch 67/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.4407 - mae: 0.5861 - mape: 16588553.0000 - val_loss: 2.5000 - val_mae: 1.5469 - val_mape: 163.4700
# Epoch 68/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3973 - mae: 0.5580 - mape: 14434636.0000 - val_loss: 2.5169 - val_mae: 1.5512 - val_mape: 164.6482
# Epoch 69/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.3574 - mae: 0.5295 - mape: 11592190.0000 - val_loss: 2.5422 - val_mae: 1.5573 - val_mape: 165.9983
# Epoch 70/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.3096 - mae: 0.4926 - mape: 9338675.0000 - val_loss: 2.5867 - val_mae: 1.5680 - val_mape: 167.9009
# Epoch 71/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.2621 - mae: 0.4515 - mape: 6834952.5000 - val_loss: 2.6590 - val_mae: 1.5841 - val_mape: 170.5917
# Epoch 72/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2165 - mae: 0.4069 - mape: 2186481.2500 - val_loss: 2.7591 - val_mae: 1.6053 - val_mape: 173.9517
# Epoch 73/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1745 - mae: 0.3693 - mape: 3224208.0000 - val_loss: 2.8869 - val_mae: 1.6315 - val_mape: 177.9112
# Epoch 74/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1369 - mae: 0.3334 - mape: 8119623.5000 - val_loss: 3.0294 - val_mae: 1.6609 - val_mape: 182.1347
# Epoch 75/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1072 - mae: 0.2959 - mape: 11616896.0000 - val_loss: 3.1730 - val_mae: 1.6903 - val_mape: 186.2535
# Epoch 76/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0834 - mae: 0.2564 - mape: 14247936.0000 - val_loss: 3.3111 - val_mae: 1.7185 - val_mape: 190.1421
# Epoch 77/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0657 - mae: 0.2140 - mape: 16833738.0000 - val_loss: 3.4447 - val_mae: 1.7460 - val_mape: 193.8456
# Epoch 78/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0538 - mae: 0.1797 - mape: 18057186.0000 - val_loss: 3.5741 - val_mae: 1.7723 - val_mape: 197.3528
# Epoch 79/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0470 - mae: 0.1729 - mape: 18613738.0000 - val_loss: 3.6938 - val_mae: 1.7973 - val_mape: 200.5907
# Epoch 80/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0434 - mae: 0.1679 - mape: 18135372.0000 - val_loss: 3.8075 - val_mae: 1.8218 - val_mape: 203.6401
# Epoch 81/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0409 - mae: 0.1647 - mape: 17120982.0000 - val_loss: 3.9041 - val_mae: 1.8446 - val_mape: 206.2905
# Epoch 82/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0380 - mae: 0.1646 - mape: 15421364.0000 - val_loss: 3.9778 - val_mae: 1.8645 - val_mape: 208.4238
# Epoch 83/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0344 - mae: 0.1577 - mape: 13218594.0000 - val_loss: 4.0249 - val_mae: 1.8805 - val_mape: 209.9391
# Epoch 84/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0281 - mae: 0.1430 - mape: 10081376.0000 - val_loss: 4.0497 - val_mae: 1.8926 - val_mape: 210.9059
# Epoch 85/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0217 - mae: 0.1245 - mape: 7256264.5000 - val_loss: 4.0534 - val_mae: 1.9002 - val_mape: 211.3209
# Epoch 86/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0153 - mae: 0.1021 - mape: 4178187.2500 - val_loss: 4.0417 - val_mae: 1.9040 - val_mape: 211.3041
# Epoch 87/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0102 - mae: 0.0827 - mape: 1505969.5000 - val_loss: 4.0190 - val_mae: 1.9045 - val_mape: 210.9540
# Epoch 88/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0071 - mae: 0.0658 - mape: 886223.0000 - val_loss: 3.9909 - val_mae: 1.9013 - val_mape: 210.3834
# Epoch 89/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0056 - mae: 0.0602 - mape: 2101827.2500 - val_loss: 3.9609 - val_mae: 1.8968 - val_mape: 209.7068
# Epoch 90/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0056 - mae: 0.0593 - mape: 3151682.2500 - val_loss: 3.9307 - val_mae: 1.8918 - val_mape: 208.9597
# Epoch 91/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0064 - mae: 0.0638 - mape: 4393717.5000 - val_loss: 3.9041 - val_mae: 1.8872 - val_mape: 208.2274
# Epoch 92/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0076 - mae: 0.0666 - mape: 5681368.5000 - val_loss: 3.8822 - val_mae: 1.8834 - val_mape: 207.5471
# Epoch 93/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0086 - mae: 0.0701 - mape: 7246577.5000 - val_loss: 3.8699 - val_mae: 1.8814 - val_mape: 207.0616
# Epoch 94/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0091 - mae: 0.0754 - mape: 8450190.0000 - val_loss: 3.8654 - val_mae: 1.8807 - val_mape: 206.7591
# Epoch 95/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0090 - mae: 0.0780 - mape: 9387702.0000 - val_loss: 3.8669 - val_mae: 1.8811 - val_mape: 206.6288
# Epoch 96/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0086 - mae: 0.0781 - mape: 9880181.0000 - val_loss: 3.8732 - val_mae: 1.8820 - val_mape: 206.6680
# Epoch 97/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0078 - mae: 0.0739 - mape: 9676827.0000 - val_loss: 3.8813 - val_mae: 1.8829 - val_mape: 206.8278
# Epoch 98/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0067 - mae: 0.0691 - mape: 8803762.0000 - val_loss: 3.8889 - val_mae: 1.8835 - val_mape: 207.0553
# Epoch 99/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0056 - mae: 0.0638 - mape: 7425620.5000 - val_loss: 3.8959 - val_mae: 1.8837 - val_mape: 207.3535
# Epoch 100/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0046 - mae: 0.0576 - mape: 5557527.0000 - val_loss: 3.9027 - val_mae: 1.8839 - val_mape: 207.7154
# Epoch 101/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0038 - mae: 0.0520 - mape: 3455518.2500 - val_loss: 3.9098 - val_mae: 1.8845 - val_mape: 208.1405
# Epoch 102/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0030 - mae: 0.0460 - mape: 1358499.2500 - val_loss: 3.9260 - val_mae: 1.8873 - val_mape: 208.7386
# Epoch 103/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0027 - mae: 0.0389 - mape: 54823.0352 - val_loss: 3.9388 - val_mae: 1.8899 - val_mape: 209.3301
# Epoch 104/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0025 - mae: 0.0366 - mape: 1259249.6250 - val_loss: 3.9433 - val_mae: 1.8914 - val_mape: 209.8037
# Epoch 105/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0023 - mae: 0.0386 - mape: 2715944.2500 - val_loss: 3.9490 - val_mae: 1.8936 - val_mape: 210.2283
# Epoch 106/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0022 - mae: 0.0398 - mape: 3339271.0000 - val_loss: 3.9562 - val_mae: 1.8964 - val_mape: 210.5862
# Epoch 107/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0019 - mae: 0.0390 - mape: 3014728.2500 - val_loss: 3.9620 - val_mae: 1.8988 - val_mape: 210.8220
# Epoch 108/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0017 - mae: 0.0386 - mape: 2457354.5000 - val_loss: 3.9574 - val_mae: 1.8988 - val_mape: 210.7457
# Epoch 109/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0014 - mae: 0.0336 - mape: 1675297.1250 - val_loss: 3.9422 - val_mae: 1.8962 - val_mape: 210.3671
# Epoch 110/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0011 - mae: 0.0276 - mape: 1250383.5000 - val_loss: 3.9210 - val_mae: 1.8917 - val_mape: 209.7713
# Epoch 111/500
# 1/1 [==============================] - 0s 58ms/step - loss: 8.8018e-04 - mae: 0.0238 - mape: 1071888.2500 - val_loss: 3.8989 - val_mae: 1.8866 - val_mape: 209.0657
# Epoch 112/500
# 1/1 [==============================] - 0s 58ms/step - loss: 7.2727e-04 - mae: 0.0214 - mape: 819813.3750 - val_loss: 3.8808 - val_mae: 1.8820 - val_mape: 208.3760
# Epoch 113/500
# 1/1 [==============================] - 0s 80ms/step - loss: 6.2699e-04 - mae: 0.0205 - mape: 408988.0000 - val_loss: 3.8682 - val_mae: 1.8783 - val_mape: 207.7689
# Epoch 114/500
# 1/1 [==============================] - 0s 68ms/step - loss: 5.6793e-04 - mae: 0.0203 - mape: 52957.6523 - val_loss: 3.8586 - val_mae: 1.8751 - val_mape: 207.2383
# Epoch 115/500
# 1/1 [==============================] - 0s 56ms/step - loss: 5.8335e-04 - mae: 0.0204 - mape: 483100.0625 - val_loss: 3.8512 - val_mae: 1.8722 - val_mape: 206.8171
# Epoch 116/500
# 1/1 [==============================] - 0s 60ms/step - loss: 5.5158e-04 - mae: 0.0188 - mape: 431955.4688 - val_loss: 3.8426 - val_mae: 1.8693 - val_mape: 206.4395
# Epoch 117/500
# 1/1 [==============================] - 0s 77ms/step - loss: 5.5059e-04 - mae: 0.0193 - mape: 203158.3594 - val_loss: 3.8348 - val_mae: 1.8667 - val_mape: 206.1354
# Epoch 118/500
# 1/1 [==============================] - 0s 57ms/step - loss: 5.7913e-04 - mae: 0.0195 - mape: 28442.3516 - val_loss: 3.8321 - val_mae: 1.8653 - val_mape: 205.9825
# Epoch 119/500
# 1/1 [==============================] - 0s 57ms/step - loss: 5.3846e-04 - mae: 0.0194 - mape: 20919.9062 - val_loss: 3.8337 - val_mae: 1.8651 - val_mape: 205.9550
# Epoch 120/500
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7866e-04 - mae: 0.0184 - mape: 165686.5000 - val_loss: 3.8365 - val_mae: 1.8654 - val_mape: 206.0022
# Epoch 121/500
# 1/1 [==============================] - 0s 72ms/step - loss: 4.2470e-04 - mae: 0.0173 - mape: 422449.5000 - val_loss: 3.8384 - val_mae: 1.8657 - val_mape: 206.0916
# Epoch 122/500
# 1/1 [==============================] - 0s 55ms/step - loss: 3.8457e-04 - mae: 0.0161 - mape: 567594.5625 - val_loss: 3.8407 - val_mae: 1.8663 - val_mape: 206.2469
# Epoch 123/500
# 1/1 [==============================] - 0s 72ms/step - loss: 3.3499e-04 - mae: 0.0153 - mape: 463766.1562 - val_loss: 3.8442 - val_mae: 1.8673 - val_mape: 206.4620
# Epoch 124/500
# 1/1 [==============================] - 0s 71ms/step - loss: 3.0495e-04 - mae: 0.0155 - mape: 284240.2812 - val_loss: 3.8509 - val_mae: 1.8690 - val_mape: 206.7523
# Epoch 125/500
# 1/1 [==============================] - 0s 66ms/step - loss: 2.8622e-04 - mae: 0.0144 - mape: 106168.6875 - val_loss: 3.8592 - val_mae: 1.8711 - val_mape: 207.0667
# Epoch 126/500
# 1/1 [==============================] - 0s 74ms/step - loss: 2.7465e-04 - mae: 0.0137 - mape: 57433.8438 - val_loss: 3.8673 - val_mae: 1.8732 - val_mape: 207.3550
# Epoch 127/500
# 1/1 [==============================] - 0s 81ms/step - loss: 2.5752e-04 - mae: 0.0126 - mape: 77539.3125 - val_loss: 3.8731 - val_mae: 1.8748 - val_mape: 207.5750
# Epoch 128/500
# 1/1 [==============================] - 0s 54ms/step - loss: 2.4047e-04 - mae: 0.0119 - mape: 16551.8945 - val_loss: 3.8745 - val_mae: 1.8754 - val_mape: 207.6778
# Epoch 129/500
# 1/1 [==============================] - 0s 59ms/step - loss: 2.1616e-04 - mae: 0.0119 - mape: 144886.1875 - val_loss: 3.8716 - val_mae: 1.8752 - val_mape: 207.6585
# Epoch 130/500
# 1/1 [==============================] - 0s 72ms/step - loss: 1.5670e-04 - mae: 0.0095 - mape: 227685.5781 - val_loss: 3.8697 - val_mae: 1.8751 - val_mape: 207.6288
# Epoch 131/500
# 1/1 [==============================] - 0s 74ms/step - loss: 1.3535e-04 - mae: 0.0095 - mape: 400632.5312 - val_loss: 3.8675 - val_mae: 1.8749 - val_mape: 207.5602
# Epoch 132/500
# 1/1 [==============================] - 0s 58ms/step - loss: 9.2214e-05 - mae: 0.0074 - mape: 295541.6875 - val_loss: 3.8678 - val_mae: 1.8752 - val_mape: 207.5252
# Epoch 133/500
# 1/1 [==============================] - 0s 73ms/step - loss: 7.1656e-05 - mae: 0.0066 - mape: 141825.8906 - val_loss: 3.8700 - val_mae: 1.8758 - val_mape: 207.5247
# Epoch 134/500
# 1/1 [==============================] - 0s 55ms/step - loss: 6.5389e-05 - mae: 0.0062 - mape: 34844.3828 - val_loss: 3.8714 - val_mae: 1.8762 - val_mape: 207.5155
# Epoch 135/500
# 1/1 [==============================] - 0s 59ms/step - loss: 6.6967e-05 - mae: 0.0063 - mape: 21028.0918 - val_loss: 3.8719 - val_mae: 1.8764 - val_mape: 207.4994
# Epoch 136/500
# 1/1 [==============================] - 0s 75ms/step - loss: 7.1294e-05 - mae: 0.0066 - mape: 30542.0508 - val_loss: 3.8721 - val_mae: 1.8765 - val_mape: 207.4848
# Epoch 137/500
# 1/1 [==============================] - 0s 59ms/step - loss: 7.4864e-05 - mae: 0.0067 - mape: 83865.2344 - val_loss: 3.8731 - val_mae: 1.8767 - val_mape: 207.4928
# Epoch 138/500
# 1/1 [==============================] - 0s 66ms/step - loss: 7.3399e-05 - mae: 0.0066 - mape: 52923.1641 - val_loss: 3.8756 - val_mae: 1.8773 - val_mape: 207.5420
# Epoch 139/500
# 1/1 [==============================] - 0s 85ms/step - loss: 6.6753e-05 - mae: 0.0063 - mape: 57767.6094 - val_loss: 3.8794 - val_mae: 1.8781 - val_mape: 207.6335
# Epoch 140/500
# 1/1 [==============================] - 0s 73ms/step - loss: 6.2960e-05 - mae: 0.0066 - mape: 222389.2188 - val_loss: 3.8846 - val_mae: 1.8792 - val_mape: 207.7823
# Epoch 141/500
# 1/1 [==============================] - 0s 85ms/step - loss: 4.6137e-05 - mae: 0.0053 - mape: 218729.6250 - val_loss: 3.8883 - val_mae: 1.8800 - val_mape: 207.9179
# Epoch 142/500
# 1/1 [==============================] - 0s 59ms/step - loss: 4.2267e-05 - mae: 0.0054 - mape: 61791.1016 - val_loss: 3.8878 - val_mae: 1.8800 - val_mape: 207.9652
# Epoch 143/500
# 1/1 [==============================] - 0s 73ms/step - loss: 4.0739e-05 - mae: 0.0053 - mape: 94226.7266 - val_loss: 3.8847 - val_mae: 1.8795 - val_mape: 207.9474
# Epoch 144/500
# 1/1 [==============================] - 0s 58ms/step - loss: 4.9873e-05 - mae: 0.0060 - mape: 218546.3906 - val_loss: 3.8800 - val_mae: 1.8788 - val_mape: 207.8668
# Epoch 145/500
# 1/1 [==============================] - 0s 61ms/step - loss: 4.2063e-05 - mae: 0.0051 - mape: 106725.8359 - val_loss: 3.8766 - val_mae: 1.8784 - val_mape: 207.7977
# Epoch 146/500
# 1/1 [==============================] - 0s 72ms/step - loss: 4.3287e-05 - mae: 0.0051 - mape: 119710.6562 - val_loss: 3.8754 - val_mae: 1.8783 - val_mape: 207.7672
# Epoch 147/500
# 1/1 [==============================] - 0s 78ms/step - loss: 4.6886e-05 - mae: 0.0052 - mape: 293395.5312 - val_loss: 3.8746 - val_mae: 1.8781 - val_mape: 207.7491
# Epoch 148/500
# 1/1 [==============================] - 0s 73ms/step - loss: 4.9785e-05 - mae: 0.0058 - mape: 373537.4688 - val_loss: 3.8746 - val_mae: 1.8778 - val_mape: 207.7570
# Epoch 149/500
# 1/1 [==============================] - 0s 57ms/step - loss: 3.6237e-05 - mae: 0.0047 - mape: 197722.7188 - val_loss: 3.8745 - val_mae: 1.8775 - val_mape: 207.7545
# Epoch 150/500
# 1/1 [==============================] - 0s 76ms/step - loss: 2.6037e-05 - mae: 0.0038 - mape: 47733.6211 - val_loss: 3.8741 - val_mae: 1.8770 - val_mape: 207.7290
# Epoch 151/500
# 1/1 [==============================] - 0s 70ms/step - loss: 1.9609e-05 - mae: 0.0037 - mape: 232727.4375 - val_loss: 3.8739 - val_mae: 1.8766 - val_mape: 207.6850
# Epoch 152/500
# 1/1 [==============================] - 0s 86ms/step - loss: 1.3355e-05 - mae: 0.0030 - mape: 246696.9062 - val_loss: 3.8747 - val_mae: 1.8765 - val_mape: 207.6518
# Epoch 153/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.1063e-05 - mae: 0.0026 - mape: 225966.9844 - val_loss: 3.8744 - val_mae: 1.8762 - val_mape: 207.5987
# Epoch 154/500
# 1/1 [==============================] - 0s 67ms/step - loss: 2.0212e-05 - mae: 0.0037 - mape: 247901.8281 - val_loss: 3.8704 - val_mae: 1.8754 - val_mape: 207.4784
# Epoch 155/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.0830e-05 - mae: 0.0025 - mape: 170902.9219 - val_loss: 3.8680 - val_mae: 1.8749 - val_mape: 207.4091
# Epoch 156/500
# 1/1 [==============================] - 0s 52ms/step - loss: 9.5388e-06 - mae: 0.0023 - mape: 209922.6719 - val_loss: 3.8676 - val_mae: 1.8750 - val_mape: 207.3969
# Epoch 157/500
# 1/1 [==============================] - 0s 71ms/step - loss: 8.7841e-06 - mae: 0.0021 - mape: 171673.4375 - val_loss: 3.8697 - val_mae: 1.8756 - val_mape: 207.4435
# Epoch 158/500
# 1/1 [==============================] - 0s 72ms/step - loss: 7.9765e-06 - mae: 0.0023 - mape: 94484.8281 - val_loss: 3.8713 - val_mae: 1.8761 - val_mape: 207.4806
# Epoch 159/500
# 1/1 [==============================] - 0s 74ms/step - loss: 1.0896e-05 - mae: 0.0024 - mape: 86388.3125 - val_loss: 3.8726 - val_mae: 1.8764 - val_mape: 207.5152
# Epoch 160/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.1931e-05 - mae: 0.0026 - mape: 181016.2344 - val_loss: 3.8729 - val_mae: 1.8765 - val_mape: 207.5316
# Epoch 161/500
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3183e-05 - mae: 0.0028 - mape: 248685.1875 - val_loss: 3.8741 - val_mae: 1.8767 - val_mape: 207.5704
# Epoch 162/500
# 1/1 [==============================] - 0s 56ms/step - loss: 6.7371e-06 - mae: 0.0019 - mape: 167963.8438 - val_loss: 3.8746 - val_mae: 1.8766 - val_mape: 207.5905
# Epoch 163/500
# 1/1 [==============================] - 0s 72ms/step - loss: 5.6929e-06 - mae: 0.0017 - mape: 120661.2969 - val_loss: 3.8753 - val_mae: 1.8767 - val_mape: 207.6109
# Epoch 164/500
# 1/1 [==============================] - 0s 69ms/step - loss: 6.1618e-06 - mae: 0.0020 - mape: 138718.8281 - val_loss: 3.8780 - val_mae: 1.8771 - val_mape: 207.6743
# Epoch 165/500
# 1/1 [==============================] - 0s 60ms/step - loss: 1.4077e-05 - mae: 0.0030 - mape: 30570.7891 - val_loss: 3.8779 - val_mae: 1.8770 - val_mape: 207.6715
# Epoch 166/500
# 1/1 [==============================] - 0s 76ms/step - loss: 9.8115e-06 - mae: 0.0027 - mape: 39825.9180 - val_loss: 3.8757 - val_mae: 1.8766 - val_mape: 207.6247
# Epoch 167/500
# 1/1 [==============================] - 0s 73ms/step - loss: 4.6363e-06 - mae: 0.0018 - mape: 47916.5000 - val_loss: 3.8738 - val_mae: 1.8763 - val_mape: 207.5820
# Epoch 168/500
# 1/1 [==============================] - 0s 67ms/step - loss: 4.4224e-06 - mae: 0.0018 - mape: 1217.0669 - val_loss: 3.8713 - val_mae: 1.8759 - val_mape: 207.5246
# Epoch 169/500
# 1/1 [==============================] - 0s 57ms/step - loss: 3.3000e-06 - mae: 0.0015 - mape: 39670.4961 - val_loss: 3.8699 - val_mae: 1.8757 - val_mape: 207.4894
# Epoch 170/500
# 1/1 [==============================] - 0s 54ms/step - loss: 3.1483e-06 - mae: 0.0014 - mape: 47290.1641 - val_loss: 3.8690 - val_mae: 1.8756 - val_mape: 207.4649
# Epoch 171/500
# 1/1 [==============================] - 0s 71ms/step - loss: 2.2504e-06 - mae: 0.0013 - mape: 25883.3477 - val_loss: 3.8675 - val_mae: 1.8753 - val_mape: 207.4292
# Epoch 172/500
# 1/1 [==============================] - 0s 54ms/step - loss: 6.6126e-06 - mae: 0.0019 - mape: 56028.2930 - val_loss: 3.8680 - val_mae: 1.8754 - val_mape: 207.4420
# Epoch 173/500
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7230e-06 - mae: 0.0011 - mape: 93887.1484 - val_loss: 3.8670 - val_mae: 1.8752 - val_mape: 207.4194
# Epoch 174/500
# 1/1 [==============================] - 0s 70ms/step - loss: 3.1042e-06 - mae: 0.0013 - mape: 71178.1484 - val_loss: 3.8682 - val_mae: 1.8754 - val_mape: 207.4461
# Epoch 175/500
# 1/1 [==============================] - 0s 72ms/step - loss: 2.0426e-06 - mae: 0.0011 - mape: 100747.3828 - val_loss: 3.8706 - val_mae: 1.8758 - val_mape: 207.5014
# Epoch 176/500
# 1/1 [==============================] - 0s 75ms/step - loss: 2.8417e-06 - mae: 0.0014 - mape: 155726.3594 - val_loss: 3.8711 - val_mae: 1.8760 - val_mape: 207.5145
# Epoch 177/500
# 1/1 [==============================] - 0s 56ms/step - loss: 3.6107e-06 - mae: 0.0015 - mape: 41378.6406 - val_loss: 3.8734 - val_mae: 1.8764 - val_mape: 207.5730
# Epoch 178/500
# 1/1 [==============================] - 0s 58ms/step - loss: 2.9976e-06 - mae: 0.0015 - mape: 111167.9531 - val_loss: 3.8734 - val_mae: 1.8765 - val_mape: 207.5813
# Epoch 179/500
# 1/1 [==============================] - 0s 53ms/step - loss: 2.0990e-05 - mae: 0.0032 - mape: 104843.6172 - val_loss: 3.8787 - val_mae: 1.8775 - val_mape: 207.7129
# Epoch 180/500
# 1/1 [==============================] - 0s 63ms/step - loss: 3.5024e-06 - mae: 0.0016 - mape: 36656.6836 - val_loss: 3.8807 - val_mae: 1.8779 - val_mape: 207.7708
# Epoch 181/500
# 1/1 [==============================] - 0s 55ms/step - loss: 3.4199e-06 - mae: 0.0016 - mape: 27923.4551 - val_loss: 3.8799 - val_mae: 1.8778 - val_mape: 207.7632
# Epoch 182/500
# 1/1 [==============================] - 0s 76ms/step - loss: 9.2410e-06 - mae: 0.0023 - mape: 107479.7969 - val_loss: 3.8760 - val_mae: 1.8771 - val_mape: 207.6769
# Epoch 183/500
# 1/1 [==============================] - 0s 75ms/step - loss: 7.8319e-06 - mae: 0.0022 - mape: 125356.9219 - val_loss: 3.8712 - val_mae: 1.8763 - val_mape: 207.5607
# Epoch 184/500
# 1/1 [==============================] - 0s 54ms/step - loss: 5.0609e-06 - mae: 0.0018 - mape: 57105.0234 - val_loss: 3.8679 - val_mae: 1.8758 - val_mape: 207.4689
# Epoch 185/500
# 1/1 [==============================] - 0s 60ms/step - loss: 4.8958e-06 - mae: 0.0019 - mape: 97031.4375 - val_loss: 3.8674 - val_mae: 1.8757 - val_mape: 207.4442
# Epoch 186/500
# 1/1 [==============================] - 0s 59ms/step - loss: 4.4918e-06 - mae: 0.0019 - mape: 190023.0781 - val_loss: 3.8678 - val_mae: 1.8758 - val_mape: 207.4495
# Epoch 187/500
# 1/1 [==============================] - 0s 60ms/step - loss: 4.3632e-06 - mae: 0.0016 - mape: 201115.7500 - val_loss: 3.8681 - val_mae: 1.8758 - val_mape: 207.4597
# Epoch 188/500
# 1/1 [==============================] - 0s 57ms/step - loss: 4.9944e-06 - mae: 0.0018 - mape: 124480.7734 - val_loss: 3.8688 - val_mae: 1.8758 - val_mape: 207.4790
# Epoch 189/500
# 1/1 [==============================] - 0s 81ms/step - loss: 3.2384e-06 - mae: 0.0015 - mape: 16090.0273 - val_loss: 3.8691 - val_mae: 1.8757 - val_mape: 207.4827
# Epoch 190/500
# 1/1 [==============================] - 0s 76ms/step - loss: 2.1271e-06 - mae: 0.0013 - mape: 79670.8984 - val_loss: 3.8695 - val_mae: 1.8756 - val_mape: 207.4780
# Epoch 191/500
# 1/1 [==============================] - 0s 76ms/step - loss: 2.4291e-06 - mae: 0.0013 - mape: 25577.3340 - val_loss: 3.8711 - val_mae: 1.8758 - val_mape: 207.5033
# Epoch 192/500
# 1/1 [==============================] - 0s 61ms/step - loss: 3.1700e-06 - mae: 0.0015 - mape: 1727.7773 - val_loss: 3.8720 - val_mae: 1.8760 - val_mape: 207.5216
# Epoch 193/500
# 1/1 [==============================] - 0s 56ms/step - loss: 5.7336e-06 - mae: 0.0019 - mape: 19241.0469 - val_loss: 3.8711 - val_mae: 1.8758 - val_mape: 207.5126
# Epoch 194/500
# 1/1 [==============================] - 0s 82ms/step - loss: 3.9286e-06 - mae: 0.0016 - mape: 66109.6719 - val_loss: 3.8700 - val_mae: 1.8757 - val_mape: 207.4999
# Epoch 195/500
# 1/1 [==============================] - 0s 86ms/step - loss: 1.4812e-06 - mae: 9.6457e-04 - mape: 86888.9688 - val_loss: 3.8702 - val_mae: 1.8759 - val_mape: 207.5127
# Epoch 196/500
# 1/1 [==============================] - 0s 78ms/step - loss: 8.2237e-07 - mae: 7.8214e-04 - mape: 34547.4883 - val_loss: 3.8718 - val_mae: 1.8763 - val_mape: 207.5493
# Epoch 197/500
# 1/1 [==============================] - 0s 86ms/step - loss: 1.9186e-06 - mae: 0.0012 - mape: 74513.6641 - val_loss: 3.8735 - val_mae: 1.8767 - val_mape: 207.5873
# Epoch 198/500
# 1/1 [==============================] - 0s 93ms/step - loss: 4.3703e-06 - mae: 0.0017 - mape: 160372.3438 - val_loss: 3.8748 - val_mae: 1.8770 - val_mape: 207.6227
# Epoch 199/500
# 1/1 [==============================] - 0s 102ms/step - loss: 4.6467e-06 - mae: 0.0017 - mape: 151810.8750 - val_loss: 3.8762 - val_mae: 1.8771 - val_mape: 207.6617
# Epoch 200/500
# 1/1 [==============================] - 0s 97ms/step - loss: 9.2192e-07 - mae: 7.1047e-04 - mape: 13644.9639 - val_loss: 3.8767 - val_mae: 1.8770 - val_mape: 207.6767
# Epoch 201/500
# 1/1 [==============================] - 0s 95ms/step - loss: 1.4823e-06 - mae: 0.0010 - mape: 108392.7344 - val_loss: 3.8767 - val_mae: 1.8769 - val_mape: 207.6713
# Epoch 202/500
# 1/1 [==============================] - 0s 78ms/step - loss: 1.6150e-06 - mae: 0.0010 - mape: 101019.3828 - val_loss: 3.8787 - val_mae: 1.8772 - val_mape: 207.7076
# Epoch 203/500
# 1/1 [==============================] - 0s 92ms/step - loss: 1.3316e-05 - mae: 0.0027 - mape: 163237.8750 - val_loss: 3.8771 - val_mae: 1.8770 - val_mape: 207.6634
# Epoch 204/500
# 1/1 [==============================] - 0s 89ms/step - loss: 2.7561e-06 - mae: 0.0014 - mape: 47825.9688 - val_loss: 3.8750 - val_mae: 1.8767 - val_mape: 207.6122
# Epoch 205/500
# 1/1 [==============================] - 0s 103ms/step - loss: 1.9478e-06 - mae: 0.0011 - mape: 32459.6211 - val_loss: 3.8724 - val_mae: 1.8763 - val_mape: 207.5542
# Epoch 206/500
# 1/1 [==============================] - 0s 99ms/step - loss: 9.9258e-07 - mae: 7.9592e-04 - mape: 22028.8867 - val_loss: 3.8698 - val_mae: 1.8759 - val_mape: 207.4957
# Epoch 207/500
# 1/1 [==============================] - 0s 116ms/step - loss: 1.3252e-06 - mae: 9.9343e-04 - mape: 14659.2002 - val_loss: 3.8682 - val_mae: 1.8757 - val_mape: 207.4566
# Epoch 208/500
# 1/1 [==============================] - 0s 77ms/step - loss: 1.6560e-05 - mae: 0.0029 - mape: 175189.3125 - val_loss: 3.8713 - val_mae: 1.8763 - val_mape: 207.5230
# Epoch 209/500
# 1/1 [==============================] - 0s 71ms/step - loss: 2.4820e-06 - mae: 0.0013 - mape: 127941.0078 - val_loss: 3.8731 - val_mae: 1.8765 - val_mape: 207.5645
# Epoch 210/500
# 1/1 [==============================] - 0s 102ms/step - loss: 1.7206e-06 - mae: 0.0010 - mape: 86716.5078 - val_loss: 3.8729 - val_mae: 1.8763 - val_mape: 207.5659
# Epoch 211/500
# 1/1 [==============================] - 0s 99ms/step - loss: 7.0797e-07 - mae: 6.6525e-04 - mape: 19869.4336 - val_loss: 3.8725 - val_mae: 1.8761 - val_mape: 207.5614
# Epoch 212/500
# 1/1 [==============================] - 0s 105ms/step - loss: 2.3297e-06 - mae: 0.0012 - mape: 149270.0625 - val_loss: 3.8722 - val_mae: 1.8760 - val_mape: 207.5512
# Epoch 213/500
# 1/1 [==============================] - 0s 77ms/step - loss: 2.5601e-06 - mae: 0.0013 - mape: 100125.6406 - val_loss: 3.8745 - val_mae: 1.8765 - val_mape: 207.5974
# Epoch 214/500
# 1/1 [==============================] - 0s 82ms/step - loss: 5.2946e-06 - mae: 0.0017 - mape: 89213.6719 - val_loss: 3.8745 - val_mae: 1.8766 - val_mape: 207.5988
# Epoch 215/500
# 1/1 [==============================] - 0s 105ms/step - loss: 1.5774e-06 - mae: 9.7011e-04 - mape: 14993.9883 - val_loss: 3.8733 - val_mae: 1.8765 - val_mape: 207.5780
# Epoch 216/500
# 1/1 [==============================] - 0s 114ms/step - loss: 3.6793e-07 - mae: 5.0604e-04 - mape: 42103.6992 - val_loss: 3.8716 - val_mae: 1.8763 - val_mape: 207.5509
# Epoch 217/500
# 1/1 [==============================] - 0s 105ms/step - loss: 2.8844e-06 - mae: 0.0012 - mape: 66712.8516 - val_loss: 3.8722 - val_mae: 1.8765 - val_mape: 207.5697
# Epoch 218/500
# 1/1 [==============================] - 0s 87ms/step - loss: 2.4206e-06 - mae: 0.0012 - mape: 63051.2695 - val_loss: 3.8740 - val_mae: 1.8768 - val_mape: 207.6099
# Epoch 219/500
# 1/1 [==============================] - 0s 97ms/step - loss: 1.2706e-06 - mae: 9.0207e-04 - mape: 67120.4141 - val_loss: 3.8749 - val_mae: 1.8769 - val_mape: 207.6281
# Epoch 220/500
# 1/1 [==============================] - 0s 84ms/step - loss: 1.5116e-06 - mae: 8.7332e-04 - mape: 30944.3906 - val_loss: 3.8736 - val_mae: 1.8766 - val_mape: 207.5954
# Epoch 221/500
# 1/1 [==============================] - 0s 87ms/step - loss: 8.6178e-07 - mae: 7.4201e-04 - mape: 30837.8750 - val_loss: 3.8715 - val_mae: 1.8761 - val_mape: 207.5433
# Epoch 222/500
# 1/1 [==============================] - 0s 87ms/step - loss: 1.3904e-06 - mae: 0.0010 - mape: 44008.1289 - val_loss: 3.8719 - val_mae: 1.8761 - val_mape: 207.5468
# Epoch 223/500
# 1/1 [==============================] - 0s 82ms/step - loss: 3.7060e-06 - mae: 0.0015 - mape: 932.5258 - val_loss: 3.8758 - val_mae: 1.8769 - val_mape: 207.6313
# Epoch 224/500
# 1/1 [==============================] - 0s 87ms/step - loss: 5.4931e-06 - mae: 0.0016 - mape: 68232.8125 - val_loss: 3.8759 - val_mae: 1.8769 - val_mape: 207.6339
# Epoch 225/500
# 1/1 [==============================] - 0s 84ms/step - loss: 3.7545e-07 - mae: 5.0160e-04 - mape: 15463.8154 - val_loss: 3.8755 - val_mae: 1.8768 - val_mape: 207.6317
# Epoch 226/500
# 1/1 [==============================] - 0s 93ms/step - loss: 4.7781e-07 - mae: 6.2002e-04 - mape: 25213.3203 - val_loss: 3.8748 - val_mae: 1.8767 - val_mape: 207.6203
# Epoch 227/500
# 1/1 [==============================] - 0s 87ms/step - loss: 6.8700e-07 - mae: 7.0266e-04 - mape: 36845.4414 - val_loss: 3.8740 - val_mae: 1.8766 - val_mape: 207.6023
# Epoch 228/500
# 1/1 [==============================] - 0s 105ms/step - loss: 2.9217e-06 - mae: 0.0012 - mape: 44847.5625 - val_loss: 3.8758 - val_mae: 1.8770 - val_mape: 207.6400
# Epoch 229/500
# 1/1 [==============================] - 0s 92ms/step - loss: 1.6957e-06 - mae: 9.2757e-04 - mape: 9508.6416 - val_loss: 3.8752 - val_mae: 1.8769 - val_mape: 207.6268
# Epoch 230/500
# 1/1 [==============================] - 0s 92ms/step - loss: 3.6533e-07 - mae: 5.1533e-04 - mape: 33608.8555 - val_loss: 3.8739 - val_mae: 1.8766 - val_mape: 207.6008
# Epoch 231/500
# 1/1 [==============================] - 0s 91ms/step - loss: 2.3590e-07 - mae: 3.9309e-04 - mape: 10542.5703 - val_loss: 3.8730 - val_mae: 1.8764 - val_mape: 207.5844
# Epoch 232/500
# 1/1 [==============================] - 0s 96ms/step - loss: 4.5383e-07 - mae: 5.4551e-04 - mape: 42169.4453 - val_loss: 3.8735 - val_mae: 1.8765 - val_mape: 207.5917
# Epoch 233/500
# 1/1 [==============================] - 0s 89ms/step - loss: 6.4276e-07 - mae: 6.3322e-04 - mape: 4299.8999 - val_loss: 3.8753 - val_mae: 1.8769 - val_mape: 207.6263
# Epoch 234/500
# 1/1 [==============================] - 0s 84ms/step - loss: 1.9936e-06 - mae: 0.0010 - mape: 22903.1914 - val_loss: 3.8742 - val_mae: 1.8767 - val_mape: 207.6001
# Epoch 235/500
# 1/1 [==============================] - 0s 99ms/step - loss: 9.0966e-07 - mae: 6.8204e-04 - mape: 52035.1562 - val_loss: 3.8739 - val_mae: 1.8766 - val_mape: 207.5926
# Epoch 236/500
# 1/1 [==============================] - 0s 92ms/step - loss: 4.0090e-07 - mae: 5.2078e-04 - mape: 8322.8301 - val_loss: 3.8726 - val_mae: 1.8763 - val_mape: 207.5648
# Epoch 237/500
# 1/1 [==============================] - 0s 98ms/step - loss: 4.8169e-07 - mae: 5.4039e-04 - mape: 44182.5938 - val_loss: 3.8712 - val_mae: 1.8760 - val_mape: 207.5315
# Epoch 238/500
# 1/1 [==============================] - 0s 93ms/step - loss: 4.6882e-07 - mae: 5.4523e-04 - mape: 37757.5391 - val_loss: 3.8704 - val_mae: 1.8759 - val_mape: 207.5085
# Epoch 239/500
# 1/1 [==============================] - 0s 87ms/step - loss: 1.0307e-06 - mae: 7.8907e-04 - mape: 23395.4219 - val_loss: 3.8692 - val_mae: 1.8757 - val_mape: 207.4768
# Epoch 240/500
# 1/1 [==============================] - 0s 101ms/step - loss: 2.3766e-07 - mae: 4.3634e-04 - mape: 24830.2812 - val_loss: 3.8679 - val_mae: 1.8756 - val_mape: 207.4462
# Epoch 241/500
# 1/1 [==============================] - 0s 100ms/step - loss: 3.0462e-06 - mae: 0.0013 - mape: 95147.8594 - val_loss: 3.8691 - val_mae: 1.8758 - val_mape: 207.4742
# ...
# Epoch 411/500
# 1/1 [==============================] - 0s 107ms/step - loss: 2.1870e-06 - mae: 0.0011 - mape: 88365.4062 - val_loss: 3.8693 - val_mae: 1.8759 - val_mape: 207.4864
# Epoch 412/500
# 1/1 [==============================] - 0s 98ms/step - loss: 8.2344e-06 - mae: 0.0023 - mape: 146677.6094 - val_loss: 3.8745 - val_mae: 1.8768 - val_mape: 207.6112
# Epoch 413/500
# 1/1 [==============================] - 0s 90ms/step - loss: 3.7157e-07 - mae: 5.0175e-04 - mape: 47587.8711 - val_loss: 3.8779 - val_mae: 1.8773 - val_mape: 207.6992
# Epoch 414/500
# 1/1 [==============================] - 0s 103ms/step - loss: 3.0318e-06 - mae: 0.0014 - mape: 78484.5234 - val_loss: 3.8771 - val_mae: 1.8771 - val_mape: 207.6847
# Epoch 415/500
# 1/1 [==============================] - 0s 98ms/step - loss: 2.9029e-06 - mae: 0.0013 - mape: 163417.6875 - val_loss: 3.8748 - val_mae: 1.8766 - val_mape: 207.6205
# Epoch 416/500
# 1/1 [==============================] - 0s 103ms/step - loss: 7.8877e-07 - mae: 7.3563e-04 - mape: 99708.4219 - val_loss: 3.8739 - val_mae: 1.8765 - val_mape: 207.5843
# Epoch 417/500
# 1/1 [==============================] - 0s 89ms/step - loss: 1.6234e-06 - mae: 0.0010 - mape: 1256.0953 - val_loss: 3.8718 - val_mae: 1.8762 - val_mape: 207.5338
# Epoch 418/500
# 1/1 [==============================] - 0s 114ms/step - loss: 1.7130e-06 - mae: 0.0012 - mape: 46974.5430 - val_loss: 3.8683 - val_mae: 1.8757 - val_mape: 207.4649
# Epoch 419/500
# 1/1 [==============================] - 0s 120ms/step - loss: 8.0656e-07 - mae: 7.3143e-04 - mape: 15614.7754 - val_loss: 3.8662 - val_mae: 1.8753 - val_mape: 207.4220
# Epoch 420/500
# 1/1 [==============================] - 0s 122ms/step - loss: 2.0999e-06 - mae: 0.0011 - mape: 17454.4180 - val_loss: 3.8667 - val_mae: 1.8755 - val_mape: 207.4230
# Epoch 421/500
# 1/1 [==============================] - 0s 83ms/step - loss: 2.4835e-06 - mae: 0.0013 - mape: 92748.5156 - val_loss: 3.8682 - val_mae: 1.8756 - val_mape: 207.4435
# Epoch 422/500
# 1/1 [==============================] - 0s 106ms/step - loss: 3.6241e-06 - mae: 0.0015 - mape: 144820.7344 - val_loss: 3.8698 - val_mae: 1.8758 - val_mape: 207.4807
# Epoch 423/500
# 1/1 [==============================] - 0s 88ms/step - loss: 6.2065e-06 - mae: 0.0019 - mape: 108013.9375 - val_loss: 3.8742 - val_mae: 1.8764 - val_mape: 207.5872
# Epoch 424/500
# 1/1 [==============================] - 0s 103ms/step - loss: 3.2188e-06 - mae: 0.0015 - mape: 18123.0195 - val_loss: 3.8800 - val_mae: 1.8774 - val_mape: 207.7310
# Epoch 425/500
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1300e-05 - mae: 0.0026 - mape: 192186.6875 - val_loss: 3.8799 - val_mae: 1.8774 - val_mape: 207.7375
# Epoch 426/500
# 1/1 [==============================] - 0s 66ms/step - loss: 8.7311e-06 - mae: 0.0023 - mape: 192468.0625 - val_loss: 3.8765 - val_mae: 1.8769 - val_mape: 207.6637
# Epoch 427/500
# 1/1 [==============================] - 0s 59ms/step - loss: 2.2028e-06 - mae: 0.0012 - mape: 71476.2734 - val_loss: 3.8744 - val_mae: 1.8768 - val_mape: 207.6155
# Epoch 428/500
# 1/1 [==============================] - 0s 80ms/step - loss: 2.0803e-06 - mae: 0.0013 - mape: 43344.7031 - val_loss: 3.8722 - val_mae: 1.8766 - val_mape: 207.5693
# Epoch 429/500
# 1/1 [==============================] - 0s 62ms/step - loss: 3.9339e-06 - mae: 0.0018 - mape: 139275.0000 - val_loss: 3.8714 - val_mae: 1.8765 - val_mape: 207.5570
# Epoch 430/500
# 1/1 [==============================] - 0s 87ms/step - loss: 4.2375e-06 - mae: 0.0017 - mape: 88475.2656 - val_loss: 3.8706 - val_mae: 1.8763 - val_mape: 207.5370
# Epoch 431/500
# 1/1 [==============================] - 0s 69ms/step - loss: 4.6860e-06 - mae: 0.0018 - mape: 25705.8594 - val_loss: 3.8713 - val_mae: 1.8762 - val_mape: 207.5399
# Epoch 432/500
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2996e-06 - mae: 9.0970e-04 - mape: 11644.3477 - val_loss: 3.8725 - val_mae: 1.8762 - val_mape: 207.5479
# Epoch 433/500
# 1/1 [==============================] - 0s 75ms/step - loss: 1.2903e-06 - mae: 8.7002e-04 - mape: 51959.2422 - val_loss: 3.8714 - val_mae: 1.8759 - val_mape: 207.5150
# Epoch 434/500
# 1/1 [==============================] - 0s 69ms/step - loss: 2.2392e-06 - mae: 0.0011 - mape: 35290.6797 - val_loss: 3.8723 - val_mae: 1.8760 - val_mape: 207.5341
# Epoch 435/500
# 1/1 [==============================] - 0s 66ms/step - loss: 3.4950e-06 - mae: 0.0013 - mape: 17341.3887 - val_loss: 3.8761 - val_mae: 1.8768 - val_mape: 207.6304
# Epoch 436/500
# 1/1 [==============================] - 0s 65ms/step - loss: 6.2800e-06 - mae: 0.0020 - mape: 61283.4570 - val_loss: 3.8750 - val_mae: 1.8767 - val_mape: 207.6169
# Epoch 437/500
# 1/1 [==============================] - 0s 80ms/step - loss: 6.9481e-06 - mae: 0.0021 - mape: 79557.6172 - val_loss: 3.8687 - val_mae: 1.8757 - val_mape: 207.4802
# Epoch 438/500
# 1/1 [==============================] - 0s 70ms/step - loss: 5.7705e-06 - mae: 0.0018 - mape: 57060.5234 - val_loss: 3.8688 - val_mae: 1.8758 - val_mape: 207.4747
# Epoch 439/500
# 1/1 [==============================] - 0s 65ms/step - loss: 5.0346e-06 - mae: 0.0016 - mape: 152421.8594 - val_loss: 3.8723 - val_mae: 1.8765 - val_mape: 207.5523
# Epoch 440/500
# 1/1 [==============================] - 0s 67ms/step - loss: 3.4318e-06 - mae: 0.0016 - mape: 180965.7656 - val_loss: 3.8751 - val_mae: 1.8769 - val_mape: 207.6310
# Epoch 441/500
# 1/1 [==============================] - 0s 82ms/step - loss: 1.2388e-06 - mae: 7.1673e-04 - mape: 4555.5630 - val_loss: 3.8755 - val_mae: 1.8768 - val_mape: 207.6527
# Epoch 442/500
# 1/1 [==============================] - 0s 66ms/step - loss: 2.6912e-06 - mae: 0.0013 - mape: 187857.6094 - val_loss: 3.8750 - val_mae: 1.8767 - val_mape: 207.6346
# Epoch 443/500
# 1/1 [==============================] - 0s 80ms/step - loss: 1.0635e-05 - mae: 0.0024 - mape: 248051.5312 - val_loss: 3.8712 - val_mae: 1.8760 - val_mape: 207.5258
# Epoch 444/500
# 1/1 [==============================] - 0s 82ms/step - loss: 2.1917e-06 - mae: 0.0012 - mape: 39689.9023 - val_loss: 3.8682 - val_mae: 1.8756 - val_mape: 207.4421
# Epoch 445/500
# 1/1 [==============================] - 0s 84ms/step - loss: 4.3655e-06 - mae: 0.0018 - mape: 161205.4844 - val_loss: 3.8688 - val_mae: 1.8758 - val_mape: 207.4620
# Epoch 446/500
# 1/1 [==============================] - 0s 79ms/step - loss: 2.1532e-06 - mae: 0.0011 - mape: 158560.2188 - val_loss: 3.8701 - val_mae: 1.8760 - val_mape: 207.5097
# Epoch 447/500
# 1/1 [==============================] - 0s 84ms/step - loss: 3.0255e-06 - mae: 0.0014 - mape: 55046.0234 - val_loss: 3.8719 - val_mae: 1.8763 - val_mape: 207.5544
# Epoch 448/500
# 1/1 [==============================] - 0s 86ms/step - loss: 3.5229e-06 - mae: 0.0016 - mape: 71887.7891 - val_loss: 3.8705 - val_mae: 1.8759 - val_mape: 207.5100
# Epoch 449/500
# 1/1 [==============================] - 0s 79ms/step - loss: 3.5307e-06 - mae: 0.0014 - mape: 9420.8438 - val_loss: 3.8725 - val_mae: 1.8762 - val_mape: 207.5383
# Epoch 450/500
# 1/1 [==============================] - 0s 63ms/step - loss: 3.1418e-06 - mae: 0.0015 - mape: 48913.5234 - val_loss: 3.8752 - val_mae: 1.8766 - val_mape: 207.6035
# Epoch 451/500
# 1/1 [==============================] - 0s 86ms/step - loss: 8.6774e-06 - mae: 0.0022 - mape: 85361.0703 - val_loss: 3.8727 - val_mae: 1.8762 - val_mape: 207.5685
# Epoch 452/500
# 1/1 [==============================] - 0s 80ms/step - loss: 1.9886e-06 - mae: 0.0011 - mape: 108561.7578 - val_loss: 3.8745 - val_mae: 1.8767 - val_mape: 207.6204
# Epoch 453/500
# 1/1 [==============================] - 0s 65ms/step - loss: 1.4173e-06 - mae: 0.0010 - mape: 101055.0234 - val_loss: 3.8758 - val_mae: 1.8771 - val_mape: 207.6494
# Epoch 454/500
# 1/1 [==============================] - 0s 79ms/step - loss: 1.9031e-06 - mae: 0.0011 - mape: 49756.4609 - val_loss: 3.8739 - val_mae: 1.8769 - val_mape: 207.6035
# Epoch 455/500
# 1/1 [==============================] - 0s 68ms/step - loss: 2.2057e-06 - mae: 0.0012 - mape: 135727.0781 - val_loss: 3.8707 - val_mae: 1.8762 - val_mape: 207.5322
# Epoch 456/500
# 1/1 [==============================] - 0s 77ms/step - loss: 1.6603e-06 - mae: 9.8860e-04 - mape: 33783.5312 - val_loss: 3.8677 - val_mae: 1.8755 - val_mape: 207.4586
# Epoch 457/500
# 1/1 [==============================] - 0s 64ms/step - loss: 1.8577e-06 - mae: 0.0011 - mape: 28046.3203 - val_loss: 3.8683 - val_mae: 1.8756 - val_mape: 207.4590
# Epoch 458/500
# 1/1 [==============================] - 0s 70ms/step - loss: 5.7646e-07 - mae: 6.5124e-04 - mape: 24278.4375 - val_loss: 3.8701 - val_mae: 1.8758 - val_mape: 207.4860
# Epoch 459/500
# 1/1 [==============================] - 0s 62ms/step - loss: 7.7303e-07 - mae: 7.7783e-04 - mape: 6723.9248 - val_loss: 3.8696 - val_mae: 1.8757 - val_mape: 207.4736
# Epoch 460/500
# 1/1 [==============================] - 0s 80ms/step - loss: 8.4817e-07 - mae: 7.3453e-04 - mape: 5911.9766 - val_loss: 3.8693 - val_mae: 1.8756 - val_mape: 207.4727
# Epoch 461/500
# 1/1 [==============================] - 0s 73ms/step - loss: 1.9778e-06 - mae: 0.0013 - mape: 81708.5781 - val_loss: 3.8671 - val_mae: 1.8752 - val_mape: 207.4240
# Epoch 462/500
# 1/1 [==============================] - 0s 68ms/step - loss: 1.0275e-06 - mae: 8.5172e-04 - mape: 34941.1680 - val_loss: 3.8660 - val_mae: 1.8751 - val_mape: 207.3925
# Epoch 463/500
# 1/1 [==============================] - 0s 98ms/step - loss: 1.4254e-05 - mae: 0.0026 - mape: 171749.1719 - val_loss: 3.8725 - val_mae: 1.8764 - val_mape: 207.5439
# Epoch 464/500
# 1/1 [==============================] - 0s 70ms/step - loss: 3.2601e-06 - mae: 0.0016 - mape: 104943.5156 - val_loss: 3.8727 - val_mae: 1.8764 - val_mape: 207.5672
# Epoch 465/500
# 1/1 [==============================] - 0s 71ms/step - loss: 3.9044e-07 - mae: 5.5137e-04 - mape: 12122.5137 - val_loss: 3.8722 - val_mae: 1.8762 - val_mape: 207.5711
# Epoch 466/500
# 1/1 [==============================] - 0s 66ms/step - loss: 1.2108e-06 - mae: 8.9791e-04 - mape: 140675.9062 - val_loss: 3.8730 - val_mae: 1.8764 - val_mape: 207.5822
# Epoch 467/500
# 1/1 [==============================] - 0s 69ms/step - loss: 1.7771e-06 - mae: 0.0011 - mape: 120946.3125 - val_loss: 3.8727 - val_mae: 1.8764 - val_mape: 207.5580
# Epoch 468/500
# 1/1 [==============================] - 0s 74ms/step - loss: 2.6258e-06 - mae: 0.0013 - mape: 10845.2109 - val_loss: 3.8694 - val_mae: 1.8758 - val_mape: 207.4813
# Epoch 469/500
# 1/1 [==============================] - 0s 68ms/step - loss: 3.1697e-06 - mae: 0.0016 - mape: 77242.1562 - val_loss: 3.8696 - val_mae: 1.8759 - val_mape: 207.4939
# Epoch 470/500
# 1/1 [==============================] - 0s 68ms/step - loss: 3.4586e-06 - mae: 0.0015 - mape: 56146.8086 - val_loss: 3.8735 - val_mae: 1.8766 - val_mape: 207.5918
# Epoch 471/500
# 1/1 [==============================] - 0s 77ms/step - loss: 3.8482e-06 - mae: 0.0016 - mape: 53509.9922 - val_loss: 3.8726 - val_mae: 1.8764 - val_mape: 207.5697
# Epoch 472/500
# 1/1 [==============================] - 0s 83ms/step - loss: 1.1216e-06 - mae: 8.9896e-04 - mape: 38766.1328 - val_loss: 3.8699 - val_mae: 1.8758 - val_mape: 207.4958
# Epoch 473/500
# 1/1 [==============================] - 0s 68ms/step - loss: 6.2062e-06 - mae: 0.0017 - mape: 70230.6953 - val_loss: 3.8731 - val_mae: 1.8763 - val_mape: 207.5569
# Epoch 474/500
# 1/1 [==============================] - 0s 65ms/step - loss: 3.0727e-06 - mae: 0.0013 - mape: 10259.9580 - val_loss: 3.8720 - val_mae: 1.8761 - val_mape: 207.5356
# Epoch 475/500
# 1/1 [==============================] - 0s 66ms/step - loss: 3.3781e-06 - mae: 0.0014 - mape: 48463.2539 - val_loss: 3.8745 - val_mae: 1.8766 - val_mape: 207.6040
# Epoch 476/500
# 1/1 [==============================] - 0s 110ms/step - loss: 2.1495e-06 - mae: 0.0012 - mape: 91044.0469 - val_loss: 3.8745 - val_mae: 1.8766 - val_mape: 207.6130
# Epoch 477/500
# 1/1 [==============================] - 0s 80ms/step - loss: 1.4515e-06 - mae: 0.0011 - mape: 23903.5605 - val_loss: 3.8770 - val_mae: 1.8772 - val_mape: 207.6699
# Epoch 478/500
# 1/1 [==============================] - 0s 89ms/step - loss: 1.8144e-06 - mae: 0.0011 - mape: 10216.0576 - val_loss: 3.8754 - val_mae: 1.8769 - val_mape: 207.6356
# Epoch 479/500
# 1/1 [==============================] - 0s 88ms/step - loss: 2.4091e-06 - mae: 0.0011 - mape: 6587.5728 - val_loss: 3.8705 - val_mae: 1.8761 - val_mape: 207.5280
# Epoch 480/500
# 1/1 [==============================] - 0s 84ms/step - loss: 2.8318e-06 - mae: 0.0014 - mape: 49080.3711 - val_loss: 3.8664 - val_mae: 1.8754 - val_mape: 207.4291
# Epoch 481/500
# 1/1 [==============================] - 0s 72ms/step - loss: 4.9671e-06 - mae: 0.0018 - mape: 32283.2129 - val_loss: 3.8685 - val_mae: 1.8758 - val_mape: 207.4648
# Epoch 482/500
# 1/1 [==============================] - 0s 89ms/step - loss: 4.1297e-06 - mae: 0.0016 - mape: 147161.3594 - val_loss: 3.8729 - val_mae: 1.8766 - val_mape: 207.5619
# Epoch 483/500
# 1/1 [==============================] - 0s 68ms/step - loss: 3.0932e-06 - mae: 0.0015 - mape: 139495.0469 - val_loss: 3.8748 - val_mae: 1.8767 - val_mape: 207.6138
# Epoch 484/500
# 1/1 [==============================] - 0s 90ms/step - loss: 2.3714e-06 - mae: 0.0013 - mape: 6938.3037 - val_loss: 3.8757 - val_mae: 1.8767 - val_mape: 207.6393
# Epoch 485/500
# 1/1 [==============================] - 0s 67ms/step - loss: 8.9567e-06 - mae: 0.0024 - mape: 224732.9375 - val_loss: 3.8720 - val_mae: 1.8759 - val_mape: 207.5417
# Epoch 486/500
# 1/1 [==============================] - 0s 80ms/step - loss: 4.4644e-06 - mae: 0.0018 - mape: 161211.3750 - val_loss: 3.8697 - val_mae: 1.8756 - val_mape: 207.4745
# Epoch 487/500
# 1/1 [==============================] - 0s 65ms/step - loss: 4.8330e-06 - mae: 0.0017 - mape: 57379.3867 - val_loss: 3.8716 - val_mae: 1.8762 - val_mape: 207.5216
# Epoch 488/500
# 1/1 [==============================] - 0s 83ms/step - loss: 1.4626e-06 - mae: 0.0010 - mape: 117478.0547 - val_loss: 3.8717 - val_mae: 1.8764 - val_mape: 207.5501
# Epoch 489/500
# 1/1 [==============================] - 0s 82ms/step - loss: 1.5658e-06 - mae: 0.0011 - mape: 61859.1875 - val_loss: 3.8716 - val_mae: 1.8764 - val_mape: 207.5648
# Epoch 490/500
# 1/1 [==============================] - 0s 64ms/step - loss: 3.7651e-06 - mae: 0.0017 - mape: 58815.6055 - val_loss: 3.8707 - val_mae: 1.8762 - val_mape: 207.5330
# Epoch 491/500
# 1/1 [==============================] - 0s 67ms/step - loss: 1.6163e-06 - mae: 0.0010 - mape: 38445.2422 - val_loss: 3.8685 - val_mae: 1.8757 - val_mape: 207.4590
# Epoch 492/500
# 1/1 [==============================] - 0s 84ms/step - loss: 2.4066e-06 - mae: 0.0014 - mape: 83445.7734 - val_loss: 3.8689 - val_mae: 1.8756 - val_mape: 207.4569
# Epoch 493/500
# 1/1 [==============================] - 0s 68ms/step - loss: 2.2467e-06 - mae: 0.0013 - mape: 63127.4180 - val_loss: 3.8706 - val_mae: 1.8759 - val_mape: 207.5068
# Epoch 494/500
# 1/1 [==============================] - 0s 65ms/step - loss: 5.3357e-07 - mae: 6.1572e-04 - mape: 52266.5234 - val_loss: 3.8731 - val_mae: 1.8763 - val_mape: 207.5746
# Epoch 495/500
# 1/1 [==============================] - 0s 63ms/step - loss: 3.1513e-06 - mae: 0.0015 - mape: 146652.5469 - val_loss: 3.8729 - val_mae: 1.8763 - val_mape: 207.5683
# Epoch 496/500
# 1/1 [==============================] - 0s 68ms/step - loss: 4.1979e-06 - mae: 0.0017 - mape: 23413.6426 - val_loss: 3.8760 - val_mae: 1.8770 - val_mape: 207.6309
# Epoch 497/500
# 1/1 [==============================] - 0s 68ms/step - loss: 1.7422e-06 - mae: 0.0011 - mape: 95981.3203 - val_loss: 3.8755 - val_mae: 1.8768 - val_mape: 207.6243
# Epoch 498/500
# 1/1 [==============================] - 0s 80ms/step - loss: 5.3458e-06 - mae: 0.0017 - mape: 10082.8457 - val_loss: 3.8690 - val_mae: 1.8756 - val_mape: 207.4889
# Epoch 499/500
# 1/1 [==============================] - 0s 66ms/step - loss: 2.0909e-06 - mae: 0.0011 - mape: 106167.6875 - val_loss: 3.8667 - val_mae: 1.8753 - val_mape: 207.4334
# Epoch 500/500
# 1/1 [==============================] - 0s 68ms/step - loss: 3.0443e-06 - mae: 0.0015 - mape: 48018.3711 - val_loss: 3.8703 - val_mae: 1.8761 - val_mape: 207.5004

# %%
# plot the loss and mape for train and validation sets
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mape'], label='train')
plt.plot(history.history['val_mape'], label='validation')
plt.title('MAPE')
plt.xlabel('Epoch')
plt.ylabel('Percentage')
plt.legend()

plt.show()

# %%
# plot and save your model
import tensorflow as tf
model_transform.summary()
img_file = 'model2.png'
tf.keras.utils.plot_model(model_transform, to_file=img_file, show_shapes=True, show_layer_names=True)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 11, 1)]      0           []
#
#  feature_input (InputLayer)     [(None, 3)]          0           []
#
#  lstm_6 (LSTM)                  (None, 11, 20)       1760        ['input_7[0][0]']
#
#  dense_53 (Dense)               (None, 100)          400         ['feature_input[0][0]']
#
#  flatten_6 (Flatten)            (None, 220)          0           ['lstm_6[0][0]']
#
#  dense_54 (Dense)               (None, 20)           2020        ['dense_53[0][0]']
#
#  dropout_12 (Dropout)           (None, 220)          0           ['flatten_6[0][0]']
#
#  dropout_14 (Dropout)           (None, 20)           0           ['dense_54[0][0]']
#
#  input_8 (InputLayer)           [(None, 9, 1)]       0           []
#
#  dense_49 (Dense)               (None, 20)           4420        ['dropout_12[0][0]']
#
#  dense_55 (Dense)               (None, 20)           420         ['dropout_14[0][0]']
#
#  lstm_7 (LSTM)                  (None, 9, 20)        1760        ['input_8[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 40)           0           ['dense_49[0][0]',
#                                                                   'dense_55[0][0]']
#
#  flatten_7 (Flatten)            (None, 180)          0           ['lstm_7[0][0]']
#
#  dense_56 (Dense)               (None, 200)          8200        ['concatenate_6[0][0]']
#
#  dropout_13 (Dropout)           (None, 180)          0           ['flatten_7[0][0]']
#
#  dropout_15 (Dropout)           (None, 200)          0           ['dense_56[0][0]']
#
#  dense_51 (Dense)               (None, 20)           3620        ['dropout_13[0][0]']
#
#  dense_57 (Dense)               (None, 11)           2211        ['dropout_15[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 31)           0           ['dense_51[0][0]',
#                                                                   'dense_57[0][0]']
#
#  dense_58 (Dense)               (None, 50)           1600        ['concatenate_7[0][0]']
#
#  dense_59 (Dense)               (None, 15)           765         ['dense_58[0][0]']
#
#  decoding_model (Functional)    (None, 9)            29849       ['dense_59[0][0]']
#
# ==================================================================================================
# Total params: 57,025
# Trainable params: 57,025
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model_decoding, to_file=img_file, show_shapes=True, show_layer_names=True)
